# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

# %%
DATASET_PATH = "../data/faces"

original_path = os.path.join(DATASET_PATH, "original")
deepfake_path = os.path.join(DATASET_PATH, "deepfakes")

print("Original path:", original_path)
print("Deepfake path:", deepfake_path)
# Out:
# Original path: ../data/faces\original
# Deepfake path: ../data/faces\deepfakes

# %%
def get_random_images(folder_path, count=6):
    images = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".jpg"):
                images.append(os.path.join(root, file))

    return random.sample(images, count)

# %%
original_samples = get_random_images(original_path, 6)
deepfake_samples = get_random_images(deepfake_path, 6)

print("Original samples:")
for img in original_samples:
    print(img)

print("\nDeepfake samples:")
for img in deepfake_samples:
    print(img)
# Out:
# Original samples:
# ../data/faces\original\481\face_0037.jpg
# ../data/faces\original\339\face_0060.jpg
# ../data/faces\original\672\face_0015.jpg
# ../data/faces\original\241\face_0059.jpg
# ../data/faces\original\134\face_0055.jpg
# ../data/faces\original\392\face_0033.jpg
#
# Deepfake samples:
# ../data/faces\deepfakes\830_828\face_0057.jpg
# ../data/faces\deepfakes\481_469\face_0003.jpg
# ../data/faces\deepfakes\339_392\face_0013.jpg
# ../data/faces\deepfakes\469_481\face_0029.jpg
# ../data/faces\deepfakes\134_192\face_0005.jpg
# ../data/faces\deepfakes\945_044\face_0015.jpg

# %%
id="1"
def show_images(image_paths, title):
    plt.figure(figsize=(12, 6))

    for i, img_path in enumerate(image_paths):
        img = Image.open(img_path)

        plt.subplot(2, 3, i + 1)
        plt.imshow(img)
        plt.axis("off")

    plt.suptitle(title, fontsize=16)
    plt.show()

# %%
show_images(original_samples, "Original Face Samples")

# %%
show_images(deepfake_samples, "Deepfake Face Samples")

# %%
from collections import Counter

def get_image_sizes(folder_path):
    sizes = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".jpg"):
                img = Image.open(os.path.join(root, file))
                sizes.append(img.size)

    return Counter(sizes)

# %%
print("Original image sizes:")
print(get_image_sizes(original_path))

print("\nDeepfake image sizes:")
print(get_image_sizes(deepfake_path))
# Out:
# Original image sizes:
# ...
